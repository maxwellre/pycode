# %%
'''
Pressure measurement of electrohydraulic pump
'''

import time
from os import walk
import os.path as ospa
import numpy as np
import re
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib notebook
# %matplotlib notebook
plt.rcParams.update({'font.size': 14})

Fs = 1000
# dataPath = ".\Data0719"
# dataPath = ".\Data0728"
dataPath = ".\Data0805"
# dataPath = ".\Data0813"

calib = np.loadtxt('Calibration20210802.txt')
print("Calibration line a = %.16f, b = %.16f" % (calib[0],calib[1]))
# Out:
# Calibration line a = 0.0497649079931161, b = 0.1217075926746309

# %%
'''
General Functions
'''

def aPlot(figName, is3D = False):
    ax = []
    
    fig1 = plt.figure(figsize = (14,4))
    fig1.suptitle(figName, fontsize=16)
    if(is3D):
        ax = fig1.add_subplot(111, projection='3d')
    else:
        ax = fig1.add_subplot(111)
        
    return ax

# %%
'''
Import data from csv files
'''

ax = aPlot('All Measurements')

presData = []
for root, directories, files in walk(dataPath):
    for fileName in files:
        condi = re.split('_|\.', fileName)[3:5]
        names = condi[0]
        
        trialNum = int(re.split('t', condi[1])[-1])
        
        data = np.genfromtxt(ospa.join(root, fileName), delimiter=',')
        dataLen = len(data)
        
        ax.plot(np.arange(dataLen)/Fs, (data-calib[1])*calib[0], color = 'k')       
        
        meanVoltage = np.mean(data[int(dataLen/2):]) - data[0]     
        meanPressure = (meanVoltage-calib[1])*calib[0]
        
        maxVoltage = np.max(data) - np.min(data);
        maxPressure = maxVoltage*calib[0]
        
        print("%s - Condition: " % root)
        print(names)
        print("trial%02d, mean-pres. = %.3f bar, max-pres. = %.3f bar (length = %d)" % 
              (trialNum, meanPressure, maxPressure, dataLen))

#######         if(trialNum > 0 and trialNum < 6):
        presData.append([names, trialNum, meanPressure, maxPressure])
        
ax.set_xlabel('Time (sec)')
ax.set_ylabel('Pressure (bar)')
        
presData = pd.DataFrame(presData, columns = ['Condition','Trial','MeanPressure','MaxPressure'])
# Out:
# .\Data0728 - Condition:
# BOPP16ShiftedU7kV
# trial00, mean-pres. = -0.006 bar, max-pres. = 0.002 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP16ShiftedU7kV
# trial01, mean-pres. = 0.070 bar, max-pres. = 0.085 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP16ShiftedU7kV
# trial02, mean-pres. = 0.061 bar, max-pres. = 0.073 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP16ShiftedU7kV
# trial03, mean-pres. = 0.049 bar, max-pres. = 0.062 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP16ShiftedU7kV
# trial04, mean-pres. = 0.068 bar, max-pres. = 0.087 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP16ShiftedU7kV
# trial05, mean-pres. = 0.045 bar, max-pres. = 0.056 bar (length = 5000)
# .\Data0728 - Condition:
# L0Ws16ShiftedU9kV
# trial00, mean-pres. = -0.007 bar, max-pres. = 0.002 bar (length = 5000)
# .\Data0728 - Condition:
# L0Ws16ShiftedU9kV
# trial01, mean-pres. = 0.108 bar, max-pres. = 0.129 bar (length = 5000)
# .\Data0728 - Condition:
# L0Ws16ShiftedU9kV
# trial02, mean-pres. = 0.074 bar, max-pres. = 0.086 bar (length = 5000)
# .\Data0728 - Condition:
# L0Ws16ShiftedU9kV
# trial03, mean-pres. = 0.067 bar, max-pres. = 0.077 bar (length = 5000)
# .\Data0728 - Condition:
# L0Ws16ShiftedU9kV
# trial04, mean-pres. = 0.079 bar, max-pres. = 0.097 bar (length = 5000)
# .\Data0728 - Condition:
# L0Ws16ShiftedU9kV
# trial05, mean-pres. = 0.065 bar, max-pres. = 0.103 bar (length = 5000)
# .\Data0728 - Condition:
# L0Ws16NoShift
# trial00, mean-pres. = -0.006 bar, max-pres. = 0.002 bar (length = 5000)
# .\Data0728 - Condition:
# L0Ws16NoShift
# trial01, mean-pres. = 0.052 bar, max-pres. = 0.061 bar (length = 5000)
# .\Data0728 - Condition:
# L0Ws16NoShift
# trial02, mean-pres. = 0.032 bar, max-pres. = 0.041 bar (length = 5000)
# .\Data0728 - Condition:
# L0Ws16NoShift
# trial03, mean-pres. = 0.023 bar, max-pres. = 0.031 bar (length = 5000)
# .\Data0728 - Condition:
# L0Ws16NoShift
# trial04, mean-pres. = 0.021 bar, max-pres. = 0.029 bar (length = 5000)
# .\Data0728 - Condition:
# L0Ws16NoShift
# trial05, mean-pres. = 0.020 bar, max-pres. = 0.052 bar (length = 5000)
# .\Data0728 - Condition:
# L0Ws16NoShift
# trial06, mean-pres. = 0.034 bar, max-pres. = 0.043 bar (length = 5000)
# .\Data0728 - Condition:
# L0Ws16NoShiftU7kV
# trial00, mean-pres. = -0.006 bar, max-pres. = 0.002 bar (length = 5000)
# .\Data0728 - Condition:
# L0Ws16NoShiftU7kV
# trial01, mean-pres. = -0.000 bar, max-pres. = 0.008 bar (length = 5000)
# .\Data0728 - Condition:
# L0Ws16NoShiftU7kV
# trial02, mean-pres. = -0.001 bar, max-pres. = 0.009 bar (length = 5000)
# .\Data0728 - Condition:
# Mylar20
# trial01, mean-pres. = 0.030 bar, max-pres. = 0.038 bar (length = 5000)
# .\Data0728 - Condition:
# Mylar20
# trial02, mean-pres. = 0.029 bar, max-pres. = 0.038 bar (length = 5000)
# .\Data0728 - Condition:
# Mylar20
# trial03, mean-pres. = 0.026 bar, max-pres. = 0.034 bar (length = 5000)
# .\Data0728 - Condition:
# Mylar20
# trial04, mean-pres. = 0.025 bar, max-pres. = 0.033 bar (length = 5000)
# .\Data0728 - Condition:
# Mylar20
# trial05, mean-pres. = 0.010 bar, max-pres. = 0.019 bar (length = 5000)
# .\Data0728 - Condition:
# Mylar20
# trial06, mean-pres. = 0.001 bar, max-pres. = 0.009 bar (length = 5000)
# .\Data0728 - Condition:
# Mylar20
# trial07, mean-pres. = 0.001 bar, max-pres. = 0.008 bar (length = 5000)
# .\Data0728 - Condition:
# Mylar20
# trial08, mean-pres. = 0.000 bar, max-pres. = 0.008 bar (length = 5000)
# .\Data0728 - Condition:
# Mylar20
# trial09, mean-pres. = 0.001 bar, max-pres. = 0.009 bar (length = 5000)
# .\Data0728 - Condition:
# Mylar20
# trial10, mean-pres. = -0.003 bar, max-pres. = 0.005 bar (length = 5000)
# .\Data0728 - Condition:
# Mylar16
# trial00, mean-pres. = -0.006 bar, max-pres. = 0.002 bar (length = 5000)
# .\Data0728 - Condition:
# Mylar16
# trial01, mean-pres. = 0.123 bar, max-pres. = 0.136 bar (length = 5000)
# .\Data0728 - Condition:
# Mylar16
# trial02, mean-pres. = 0.103 bar, max-pres. = 0.114 bar (length = 5000)
# .\Data0728 - Condition:
# Mylar16
# trial03, mean-pres. = 0.107 bar, max-pres. = 0.119 bar (length = 5000)
# .\Data0728 - Condition:
# Mylar16
# trial04, mean-pres. = 0.104 bar, max-pres. = 0.121 bar (length = 5000)
# .\Data0728 - Condition:
# Mylar16
# trial05, mean-pres. = 0.081 bar, max-pres. = 0.096 bar (length = 5000)
# .\Data0728 - Condition:
# Mylar16
# trial06, mean-pres. = 0.076 bar, max-pres. = 0.096 bar (length = 5000)
# .\Data0728 - Condition:
# Mylar16
# trial07, mean-pres. = 0.068 bar, max-pres. = 0.090 bar (length = 5000)
# .\Data0728 - Condition:
# Mylar16
# trial08, mean-pres. = 0.063 bar, max-pres. = 0.081 bar (length = 5000)
# .\Data0728 - Condition:
# Mylar16
# trial09, mean-pres. = 0.058 bar, max-pres. = 0.075 bar (length = 5000)
# .\Data0728 - Condition:
# Mylar16
# trial10, mean-pres. = 0.070 bar, max-pres. = 0.082 bar (length = 5000)
# .\Data0728 - Condition:
# Mylar16NoShift
# trial00, mean-pres. = -0.006 bar, max-pres. = 0.002 bar (length = 5000)
# .\Data0728 - Condition:
# Mylar16NoShift
# trial01, mean-pres. = 0.152 bar, max-pres. = 0.171 bar (length = 5000)
# .\Data0728 - Condition:
# Mylar16NoShift
# trial02, mean-pres. = 0.136 bar, max-pres. = 0.145 bar (length = 5000)
# .\Data0728 - Condition:
# Mylar16NoShift
# trial03, mean-pres. = 0.152 bar, max-pres. = 0.178 bar (length = 5000)
# .\Data0728 - Condition:
# Mylar16NoShift
# trial04, mean-pres. = 0.151 bar, max-pres. = 0.165 bar (length = 5000)
# .\Data0728 - Condition:
# Mylar16NoShift
# trial05, mean-pres. = 0.080 bar, max-pres. = 0.108 bar (length = 5000)
# .\Data0728 - Condition:
# Mylar16NoShift
# trial06, mean-pres. = 0.103 bar, max-pres. = 0.120 bar (length = 5000)
# .\Data0728 - Condition:
# Mylar16NoShift
# trial07, mean-pres. = 0.066 bar, max-pres. = 0.092 bar (length = 5000)
# .\Data0728 - Condition:
# Mylar16NoShift
# trial08, mean-pres. = 0.065 bar, max-pres. = 0.091 bar (length = 5000)
# .\Data0728 - Condition:
# Mylar16NoShift
# trial09, mean-pres. = 0.064 bar, max-pres. = 0.078 bar (length = 5000)
# .\Data0728 - Condition:
# Mylar16NoShift
# trial10, mean-pres. = 0.053 bar, max-pres. = 0.080 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP16
# trial00, mean-pres. = -0.006 bar, max-pres. = 0.002 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP16
# trial01, mean-pres. = 0.068 bar, max-pres. = 0.079 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP16
# trial02, mean-pres. = 0.047 bar, max-pres. = 0.057 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP16
# trial03, mean-pres. = 0.032 bar, max-pres. = 0.042 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP16
# trial04, mean-pres. = 0.028 bar, max-pres. = 0.038 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP16
# trial05, mean-pres. = 0.030 bar, max-pres. = 0.040 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP16
# trial06, mean-pres. = 0.030 bar, max-pres. = 0.038 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP16
# trial07, mean-pres. = 0.021 bar, max-pres. = 0.032 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP16
# trial08, mean-pres. = 0.022 bar, max-pres. = 0.032 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP16
# trial09, mean-pres. = 0.023 bar, max-pres. = 0.035 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP16
# trial10, mean-pres. = 0.016 bar, max-pres. = 0.026 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP20
# trial00, mean-pres. = -0.006 bar, max-pres. = 0.002 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP20
# trial01, mean-pres. = 0.055 bar, max-pres. = 0.073 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP20
# trial02, mean-pres. = 0.056 bar, max-pres. = 0.070 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP20
# trial03, mean-pres. = 0.021 bar, max-pres. = 0.030 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP20
# trial04, mean-pres. = 0.021 bar, max-pres. = 0.029 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP20
# trial05, mean-pres. = 0.030 bar, max-pres. = 0.041 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP20
# trial06, mean-pres. = 0.040 bar, max-pres. = 0.053 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP20
# trial07, mean-pres. = 0.017 bar, max-pres. = 0.026 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP20
# trial08, mean-pres. = 0.017 bar, max-pres. = 0.025 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP20
# trial09, mean-pres. = 0.017 bar, max-pres. = 0.027 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP20
# trial10, mean-pres. = 0.015 bar, max-pres. = 0.024 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP16U9kV
# trial00, mean-pres. = -0.006 bar, max-pres. = 0.002 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP16U9kV
# trial01, mean-pres. = 0.074 bar, max-pres. = 0.094 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP16U9kV
# trial02, mean-pres. = 0.046 bar, max-pres. = 0.059 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP16U9kV
# trial03, mean-pres. = 0.030 bar, max-pres. = 0.042 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP16U9kV
# trial04, mean-pres. = 0.031 bar, max-pres. = 0.042 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP16U9kV
# trial05, mean-pres. = 0.023 bar, max-pres. = 0.035 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP20U9kV
# trial00, mean-pres. = -0.006 bar, max-pres. = 0.002 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP20U9kV
# trial01, mean-pres. = 0.056 bar, max-pres. = 0.085 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP20U9kV
# trial02, mean-pres. = 0.038 bar, max-pres. = 0.049 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP20U9kV
# trial03, mean-pres. = 0.042 bar, max-pres. = 0.050 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP20U9kV
# trial04, mean-pres. = 0.042 bar, max-pres. = 0.064 bar (length = 5000)
# .\Data0728 - Condition:
# BOPP20U9kV
# trial05, mean-pres. = -0.009 bar, max-pres. = 0.009 bar (length = 5000)

# %%
################## presData = pd.read_csv('MergedProsssed0719and0728.csv'); presData.head()

# %%
condiNames = pd.unique(presData['Condition'])
condiNum = len(condiNames)
print("In total %d conditions: %s" % (condiNum, condiNames))

################## condiNames = condiNames[[4,5,0,1,2,3,7,8,15,16,9,11,12,10,6,13,14]]
# Out:
# In total 11 conditions: ['BOPP16ShiftedU7kV' 'L0Ws16ShiftedU9kV' 'L0Ws16NoShift'
#  'L0Ws16NoShiftU7kV' 'Mylar20' 'Mylar16' 'Mylar16NoShift' 'BOPP16'
#  'BOPP20' 'BOPP16U9kV' 'BOPP20U9kV']

# %%
# select_ind = (presData['Trial'] > 0) & (presData['Trial'] < 6) 
select_ind = (presData['Trial'] > 0)
# for condi in condiNames:
#     condiAvgMax = np.mean(presData.loc[(presData['Condition'] == condi) & select_ind, 'MaxPressure'])
#     print("%s - avg. max pressure = %.3f bar" % (condi, condiAvgMax))
# print("-------------------------------------")

for condi in condiNames:
    condiMaxMax = np.max(presData.loc[presData['Condition'] == condi, 'MaxPressure'])
    print("%s - max pressure = %.3f bar" % (condi, condiMaxMax))
# Out:
# BOPP16ShiftedU7kV - max pressure = 0.087 bar
# L0Ws16ShiftedU9kV - max pressure = 0.129 bar
# L0Ws16NoShift - max pressure = 0.061 bar
# L0Ws16NoShiftU7kV - max pressure = 0.009 bar
# Mylar20 - max pressure = 0.038 bar
# Mylar16 - max pressure = 0.136 bar
# Mylar16NoShift - max pressure = 0.178 bar
# BOPP16 - max pressure = 0.079 bar
# BOPP20 - max pressure = 0.073 bar
# BOPP16U9kV - max pressure = 0.094 bar
# BOPP20U9kV - max pressure = 0.085 bar

# %%
# select_ind = (presData['Trial'] > 0) & (presData['Trial'] < 6) 
select_ind = (presData['Trial'] > 0)

ax = aPlot('Maximum Pressure Increased')
for i in range(condiNum):
    temp = presData.loc[(presData['Condition'] == condiNames[i]) & select_ind, 'MaxPressure']
    ax.scatter(i*np.ones(temp.size), temp, linewidths = 5)
ax.set_xticks(range(condiNum))
ax.set_xticklabels(condiNames, rotation=80)
ax.set_xlabel('Conditions')
ax.set_ylabel('Pressure (bar)')
plt.show()

# %%
# ax = aPlot('Mean Pressure (over the last 2.5-second duration)')
# for i in range(condiNum):
#     temp = presData.loc[presData['Condition'] == condiNames[i], 'MeanPressure']
#     ax.scatter(i*np.ones(temp.size), temp, linewidths = 5)
# ax.set_xticks(range(condiNum))
# ax.set_xticklabels(condiNames, rotation=30)
# ax.set_xlabel('Conditions')
# ax.set_ylabel('Pressure (bar)')
# plt.show()

# %%
############# presData0719 = presData
############# condiNames0719 = condiNames
############# presData = np.concatenate((presData0719, presData), axis = 0)
############# condiNames = np.concatenate((condiNames0719, condiNames), axis = 0)
############# np.savetxt("MergedProsssed0719and0728.csv", presData, fmt = '%s,%d,%.16f,%.16f', 
#############            header = 'Condition,Trial,MeanPressure,MaxPressure', comments='')
############# np.savetxt("MergedProsssed0719and0728_CondiNames.csv", condiNames, fmt = '%s')
