# %%
'''
Pressure measurement of electrohydraulic pump
'''

import time
from os import walk
import os.path as ospa
import numpy as np
import re
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib notebook
# %matplotlib notebook
plt.rcParams.update({'font.size': 14})

Fs = 1000

dataPath = ".\Data0813"

calib = np.loadtxt('Calibration20210802.txt')
print("Calibration line a = %.16f, b = %.16f" % (calib[0],calib[1]))
# Out:
# Calibration line a = 0.0497649079931161, b = 0.1217075926746309

# %%
'''
General Functions
'''

def aPlot(figName, is3D = False):
    ax = []
    
    fig1 = plt.figure(figsize = (10,4))
    fig1.suptitle(figName, fontsize=16)
    if(is3D):
        ax = fig1.add_subplot(111, projection='3d')
    else:
        ax = fig1.add_subplot(111)
        
    return ax

# %%
'''
Import data from csv files
'''

ax = aPlot('All Measurements')

start_ind = ((np.array([1, 8, 15]) - 0.1) * Fs).astype(int)
end_ind = ((np.array([5, 12, 19]) + 0.1) * Fs).astype(int)

presData = []
for root, directories, files in walk(dataPath):
    for fileName in files:
        condi = re.split('_|\.', fileName)[3:5]
        names = condi[0]
        
        trialNum = int(re.split('t', condi[1])[-1])
        
        data = np.genfromtxt(ospa.join(root, fileName), delimiter=',')
        dataLen = len(data)

#         ax.plot(np.arange(end_ind[0]-start_ind[0])/Fs, (data[start_ind[0]:end_ind[0]]-calib[0])*calib[0])  
        ax.plot(np.arange(dataLen)/Fs, (data-calib[1])*calib[0], 'k')       
        ax.plot(np.arange(start_ind[1],end_ind[1])/Fs, (data[start_ind[1]:end_ind[1]]-calib[1])*calib[0], 'y--')   
        
        if(trialNum > 0):
            for i in range(3):  
                meanVoltage = np.mean(data[start_ind[i]:end_ind[i]]) - data[0]     
                meanPressure = (meanVoltage-calib[1])*calib[0]

                maxVoltage = np.max(data[start_ind[i]:end_ind[i]]) - np.min(data[start_ind[i]:end_ind[i]]);
                maxPressure = maxVoltage*calib[0]

                print("%s - Condition: " % root)
                print(names)
                print("trial%02d, mean-pres. = %.3f bar, max-pres. = %.3f bar (length = %d)" % 
                      ((trialNum-1)*3+i+1, meanPressure, maxPressure, dataLen))

                presData.append([names, (trialNum-1)*3+i+1, meanPressure, maxPressure])

for i in range(3):
    ax.plot(start_ind[[i,i]]/Fs, [0, 0.25], 'r-')
    ax.plot(end_ind[[i,i]]/Fs, [0, 0.25], 'b-')
ax.set_xlabel('Time (sec)')
ax.set_ylabel('Pressure (bar)')
        
presData = pd.DataFrame(presData, columns = ['Condition','Trial','MeanPressure','MaxPressure'])
# Out:
# .\Data0813 - Condition:
# MLSi16SB7kV
# trial01, mean-pres. = 0.010 bar, max-pres. = 0.074 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi16SB7kV
# trial02, mean-pres. = -0.000 bar, max-pres. = 0.016 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi16SB7kV
# trial03, mean-pres. = -0.000 bar, max-pres. = 0.012 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi16SB7kV
# trial07, mean-pres. = 0.026 bar, max-pres. = 0.076 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi16SB7kV
# trial08, mean-pres. = 0.023 bar, max-pres. = 0.048 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi16SB7kV
# trial09, mean-pres. = 0.016 bar, max-pres. = 0.036 bar (length = 20000)
# .\Data0813 - Condition:
# MLIC20SB7kV
# trial01, mean-pres. = 0.051 bar, max-pres. = 0.073 bar (length = 20000)
# .\Data0813 - Condition:
# MLIC20SB7kV
# trial02, mean-pres. = 0.036 bar, max-pres. = 0.041 bar (length = 20000)
# .\Data0813 - Condition:
# MLIC20SB7kV
# trial03, mean-pres. = 0.016 bar, max-pres. = 0.008 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi16SB7kV
# trial10, mean-pres. = 0.054 bar, max-pres. = 0.086 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi16SB7kV
# trial11, mean-pres. = 0.034 bar, max-pres. = 0.058 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi16SB7kV
# trial12, mean-pres. = 0.034 bar, max-pres. = 0.062 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi16SB7kV
# trial13, mean-pres. = 0.070 bar, max-pres. = 0.129 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi16SB7kV
# trial14, mean-pres. = 0.053 bar, max-pres. = 0.109 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi16SB7kV
# trial15, mean-pres. = 0.044 bar, max-pres. = 0.053 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi16CB7kV
# trial01, mean-pres. = 0.076 bar, max-pres. = 0.105 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi16CB7kV
# trial02, mean-pres. = 0.066 bar, max-pres. = 0.099 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi16CB7kV
# trial03, mean-pres. = 0.062 bar, max-pres. = 0.094 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi16CB7kV
# trial04, mean-pres. = 0.055 bar, max-pres. = 0.103 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi16CB7kV
# trial05, mean-pres. = 0.036 bar, max-pres. = 0.044 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi16CB7kV
# trial06, mean-pres. = 0.034 bar, max-pres. = 0.050 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi16CB7kV
# trial07, mean-pres. = 0.029 bar, max-pres. = 0.055 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi16CB7kV
# trial08, mean-pres. = 0.026 bar, max-pres. = 0.041 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi16CB7kV
# trial09, mean-pres. = 0.023 bar, max-pres. = 0.045 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi16CB7kVMoreOil
# trial10, mean-pres. = 0.092 bar, max-pres. = 0.150 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi16CB7kVMoreOil
# trial11, mean-pres. = 0.074 bar, max-pres. = 0.126 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi16CB7kVMoreOil
# trial12, mean-pres. = 0.061 bar, max-pres. = 0.106 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi20SB7kV
# trial01, mean-pres. = 0.077 bar, max-pres. = 0.140 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi20SB7kV
# trial02, mean-pres. = 0.041 bar, max-pres. = 0.099 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi20SB7kV
# trial03, mean-pres. = 0.043 bar, max-pres. = 0.076 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi20SB7kV
# trial04, mean-pres. = 0.030 bar, max-pres. = 0.073 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi20SB7kV
# trial05, mean-pres. = 0.021 bar, max-pres. = 0.074 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi20SB7kV
# trial06, mean-pres. = 0.015 bar, max-pres. = 0.072 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi20B7kV
# trial01, mean-pres. = 0.070 bar, max-pres. = 0.170 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi20B7kV
# trial02, mean-pres. = 0.042 bar, max-pres. = 0.016 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi20B7kV
# trial03, mean-pres. = 0.029 bar, max-pres. = 0.010 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi20B7kV
# trial04, mean-pres. = -0.006 bar, max-pres. = 0.005 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi20B7kV
# trial05, mean-pres. = -0.010 bar, max-pres. = 0.006 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi20B7kV
# trial06, mean-pres. = -0.012 bar, max-pres. = 0.005 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi20B7kV
# trial07, mean-pres. = 0.082 bar, max-pres. = 0.205 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi20B7kV
# trial08, mean-pres. = 0.102 bar, max-pres. = 0.217 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi20B7kV
# trial09, mean-pres. = 0.071 bar, max-pres. = 0.147 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi20B7kV
# trial10, mean-pres. = 0.113 bar, max-pres. = 0.225 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi20B7kV
# trial11, mean-pres. = 0.116 bar, max-pres. = 0.258 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi20B7kV
# trial12, mean-pres. = 0.104 bar, max-pres. = 0.270 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi20B7kV
# trial13, mean-pres. = 0.092 bar, max-pres. = 0.196 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi20B7kV
# trial14, mean-pres. = 0.101 bar, max-pres. = 0.224 bar (length = 20000)
# .\Data0813 - Condition:
# MLSi20B7kV
# trial15, mean-pres. = 0.003 bar, max-pres. = 0.229 bar (length = 20000)

# %%
################## presData = pd.read_csv('MergedProsssed0719and0728.csv'); presData.head()

# %%
condiNames = pd.unique(presData['Condition'])
condiNum = len(condiNames)
print("In total %d conditions: %s" % (condiNum, condiNames))

################## condiNames = condiNames[[4,5,0,1,2,3,7,8,15,16,9,11,12,10,6,13,14]]
# Out:
# In total 6 conditions: ['MLSi16SB7kV' 'MLIC20SB7kV' 'MLSi16CB7kV' 'MLSi16CB7kVMoreOil'
#  'MLSi20SB7kV' 'MLSi20B7kV']

# %%
# select_ind = (presData['Trial'] > 0) & (presData['Trial'] < 6) 
select_ind = (presData['Trial'] > 0)
# for condi in condiNames:
#     condiAvgMax = np.mean(presData.loc[(presData['Condition'] == condi) & select_ind, 'MaxPressure'])
#     print("%s - avg. max pressure = %.3f bar" % (condi, condiAvgMax))
# print("-------------------------------------")

for condi in condiNames:
    condiMaxMax = np.max(presData.loc[presData['Condition'] == condi, 'MaxPressure'])
    print("%s - max pressure = %.3f bar" % (condi, condiMaxMax))
# Out:
# MLSi16SB7kV - max pressure = 0.129 bar
# MLIC20SB7kV - max pressure = 0.073 bar
# MLSi16CB7kV - max pressure = 0.105 bar
# MLSi16CB7kVMoreOil - max pressure = 0.154 bar
# MLSi20SB7kV - max pressure = 0.140 bar
# MLSi20B7kV - max pressure = 0.270 bar

# %%
# select_ind = (presData['Trial'] > 0) & (presData['Trial'] < 6) 
select_ind = (presData['Trial'] > 0)

ax = aPlot('Maximum Pressure Increased')
for i in range(condiNum):
    temp = presData.loc[(presData['Condition'] == condiNames[i]) & select_ind, 'MaxPressure']
    ax.scatter(i*np.ones(temp.size), temp, linewidths = 5)
ax.set_xticks(range(condiNum))
ax.set_xticklabels(condiNames, rotation=80)
ax.set_xlabel('Conditions')
ax.set_ylabel('Pressure (bar)')
plt.show()

# %%
# ax = aPlot('Mean Pressure (over the last 2.5-second duration)')
# for i in range(condiNum):
#     temp = presData.loc[presData['Condition'] == condiNames[i], 'MeanPressure']
#     ax.scatter(i*np.ones(temp.size), temp, linewidths = 5)
# ax.set_xticks(range(condiNum))
# ax.set_xticklabels(condiNames, rotation=30)
# ax.set_xlabel('Conditions')
# ax.set_ylabel('Pressure (bar)')
# plt.show()

# %%
############# presData0719 = presData
############# condiNames0719 = condiNames
############# presData = np.concatenate((presData0719, presData), axis = 0)
############# condiNames = np.concatenate((condiNames0719, condiNames), axis = 0)
############# np.savetxt("MergedProsssed0719and0728.csv", presData, fmt = '%s,%d,%.16f,%.16f', 
#############            header = 'Condition,Trial,MeanPressure,MaxPressure', comments='')
############# np.savetxt("MergedProsssed0719and0728_CondiNames.csv", condiNames, fmt = '%s')
